# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
retail = pd.read_csv('MarketingData/Online_Sales.csv')

# %%
retail = pd.read_csv('store_data.csv', header=None, names=['Product_Description'], sep='\t')

# %%
retail.reset_index(inplace=True, names=['Transaction_ID'])

# %%
retail['Product_Description'] = retail['Product_Description'].str.split(',')

# %%
retail = retail.explode('Product_Description', ignore_index=True)

# %%
retail['Product_Description'].dropna(inplace=True)
retail = retail.loc[retail['Product_Description'] != '', :]

# %%
retail['Quantity'] = 1

# %%
retail.head()
# Out:
#    Transaction_ID Product_Description  Quantity
# 0               0              shrimp         1
# 1               0             almonds         1
# 2               0             avocado         1
# 3               0      vegetables mix         1
# 4               0        green grapes         1

# %%
market_basket = retail.groupby(['Transaction_ID','Product_Description']).size().to_frame('count').unstack().fillna(0)

# %%
market_basket.columns = market_basket.columns.droplevel()

# %%
def encoding(x):
    if x<=0: return False
    else: return True

# %%
market_basket = market_basket.map(encoding)

# %%
frequent_items = apriori(market_basket, min_support=0.005, use_colnames=True)
rules = association_rules(frequent_items, metric='lift', min_threshold=1)
rules.sort_values('confidence', ascending=False, inplace=True)

# %%
rules
# Out:
#                          antecedents                   consequents  \
# 1532       (frozen vegetables, soup)               (mineral water)
# 1773               (olive oil, soup)               (mineral water)
# 1513  (olive oil, frozen vegetables)               (mineral water)
# 1732                    (soup, milk)               (mineral water)
# 1201               (chocolate, soup)               (mineral water)
# ...                              ...                           ...
# 1533                 (mineral water)     (frozen vegetables, soup)
# 1569                 (mineral water)  (grated cheese, ground beef)
# 1655                 (mineral water)         (shrimp, ground beef)
# 1661                 (mineral water)           (soup, ground beef)
# 1758                 (mineral water)      (whole wheat rice, milk)
#
#       antecedent support  consequent support   support  confidence      lift  \
# 1532            0.007999            0.238368  0.005066    0.633333  2.656954
# ...

# %%
sns.histplot(np.log10(rules['confidence']));

# %% [markdown]
# Slow moving items

# %%
items_move = retail.groupby('Product_Description').agg({'Quantity':'sum'})

# %%
items_move.sort_values('Quantity', ascending=False)
# Out:
#                      Quantity
# Product_Description
# mineral water            1788
# eggs                     1348
# spaghetti                1306
# french fries             1282
# chocolate                1230
# ...                       ...
# bramble                    14
# cream                       7
# napkins                     5
# water spray                 3
#  asparagus                  1
#
# [120 rows x 1 columns]

# %%
sns.histplot(np.log10(items_move['Quantity']))
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
sns.histplot(items_move['Quantity'])
# Out:
# <Axes: xlabel='Quantity', ylabel='Count'>

# %%
items_move['cut'] = pd.qcut(items_move['Quantity'], 10, labels=False)

# %%
slower_moving_items = items_move[items_move['Quantity']<=250].index.unique()

# %%
len(slower_moving_items)
# Out:
# 89

# %%
rules = rules.explode('consequents')

# %%
rules.loc[(rules['consequents'].isin(slower_moving_items))]
# Out:
#            antecedents           consequents  antecedent support  \
# 754        (olive oil)     whole wheat pasta            0.065858
# 19   (frozen smoothie)               avocado            0.063325
# 694             (milk)     whole wheat pasta            0.129583
# 376         (escalope)                 pasta            0.079323
# 374         (escalope)  mushroom cream sauce            0.079323
# ..                 ...                   ...                 ...
# 384    (mineral water)  extra dark chocolate            0.238368
# 726    (mineral water)          tomato sauce            0.238368
# 29     (mineral water)             black tea            0.238368
# 144    (mineral water)               carrots            0.238368
# 701    (mineral water)           nonfat milk            0.238368
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 754            0.029463  0.007999    0.121457  4.122410  0.006059    1.104713
# ...

# %%
import streamlit as st

# %%
st.cache_data.clear()
